# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

Bank=pd.read_csv("BankPaymentData.csv")

# %%
Bank
# Out:
#         month  year  month_number start_date  end_date  \
# 0     January  2017             1   01-01-17  31-01-17
# 1     January  2017             1   01-01-17  31-01-17
# 2     January  2017             1   01-01-17  31-01-17
# 3     January  2017             1   01-01-17  31-01-17
# 4     January  2017             1   01-01-17  31-01-17
# ...       ...   ...           ...        ...       ...
# 1864   August  2019             8   01-08-19  31-08-19
# 1865   August  2019             8   01-08-19  31-08-19
# 1866   August  2019             8   01-08-19  31-08-19
# 1867   August  2019             8   01-08-19  31-08-19
# 1868   August  2019             8   01-08-19  31-08-19
#
#                                   bank_name  no_atms_on_site  \
# 0                            ALLAHABAD BANK              820
# 1                               ANDHRA BANK             2971
# 2                            BANK OF BARODA             6287
# ...

# %%
Bank.describe()
# Out:
#               year  month_number  no_atms_on_site  no_atms_off_site  \
# count  1869.000000   1869.000000      1869.000000       1869.000000
# mean   2017.949706      6.010166      1856.340289       1674.971108
# std       0.775451      3.289462      3697.362933       4499.706797
# min    2017.000000      1.000000         0.000000          0.000000
# 25%    2017.000000      3.000000       102.000000         23.000000
# 50%    2018.000000      6.000000       760.000000        478.000000
# 75%    2019.000000      8.000000      2339.000000        996.000000
# max    2019.000000     12.000000     29254.000000      33209.000000
#
#        no_pos_on_line  no_pos_off_line  no_credit_cards  \
# count     1869.000000      1869.000000     1.866000e+03
# mean     55284.601926         4.196362     6.694027e+05
# std     135536.510288        77.545735     1.887198e+06
# min          0.000000         0.000000     0.000000e+00
# 25%          0.000000         0.000000     0.000000e+00
# ...

# %%
Bank.dtypes
# Out:
# month                      object
# year                        int64
# month_number                int64
# start_date                 object
# end_date                   object
# bank_name                  object
# no_atms_on_site             int64
# no_atms_off_site            int64
# no_pos_on_line              int64
# no_pos_off_line             int64
# no_credit_cards           float64
# no_credit_card_atm_txn      int64
# no_credit_card_pos_txn      int64
# no_debit_cards              int64
# no_debit_card_atm_txn       int64
# no_debit_card_pos_txn       int64
# dtype: object

# %%
Bank.index
# Out:
# RangeIndex(start=0, stop=1869, step=1)

# %%
Bank.shape
# Out:
# (1869, 16)

# %%
Bank.columns
# Out:
# Index(['month', 'year', 'month_number', 'start_date', 'end_date', 'bank_name',
#        'no_atms_on_site', 'no_atms_off_site', 'no_pos_on_line',
#        'no_pos_off_line', 'no_credit_cards', 'no_credit_card_atm_txn',
#        'no_credit_card_pos_txn', 'no_debit_cards', 'no_debit_card_atm_txn',
#        'no_debit_card_pos_txn'],
#       dtype='object')

# %%
Bank.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1869 entries, 0 to 1868
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   month                   1869 non-null   object
#  1   year                    1869 non-null   int64
#  2   month_number            1869 non-null   int64
#  3   start_date              1869 non-null   object
#  4   end_date                1869 non-null   object
#  5   bank_name               1869 non-null   object
#  6   no_atms_on_site         1869 non-null   int64
#  7   no_atms_off_site        1869 non-null   int64
#  8   no_pos_on_line          1869 non-null   int64
#  9   no_pos_off_line         1869 non-null   int64
#  10  no_credit_cards         1866 non-null   float64
#  11  no_credit_card_atm_txn  1869 non-null   int64
#  12  no_credit_card_pos_txn  1869 non-null   int64
#  13  no_debit_cards          1869 non-null   int64
# ...

# %%
Bank.mean()
# Out:
# year                      2.017950e+03
# month_number              6.010166e+00
# no_atms_on_site           1.856340e+03
# no_atms_off_site          1.674971e+03
# no_pos_on_line            5.528460e+04
# no_pos_off_line           4.196362e+00
# no_credit_cards           6.694027e+05
# no_credit_card_atm_txn    1.242626e+04
# no_credit_card_pos_txn    2.324439e+06
# no_debit_cards            1.490442e+07
# no_debit_card_atm_txn     1.317584e+07
# no_debit_card_pos_txn     5.723367e+06
# dtype: float64

# %%
maxvalue=Bank[['no_atms_on_site','no_atms_off_site','no_pos_on_line','no_pos_off_line','no_credit_cards','no_credit_card_atm_txn',
               'no_credit_card_pos_txn','no_debit_cards','no_debit_card_atm_txn','no_debit_card_pos_txn']].mean()
print("maximum value is:")
print(maxvalue)

maximum=np.max(maxvalue)
print("\nThe Maximum value is::",maximum)

print("\nWe can predict that debit card is the most used methods by users")
# Out:
# maximum value is:
# no_atms_on_site           1.856340e+03
# no_atms_off_site          1.674971e+03
# no_pos_on_line            5.528460e+04
# no_pos_off_line           4.196362e+00
# no_credit_cards           6.694027e+05
# no_credit_card_atm_txn    1.242626e+04
# no_credit_card_pos_txn    2.324439e+06
# no_debit_cards            1.490442e+07
# no_debit_card_atm_txn     1.317584e+07
# no_debit_card_pos_txn     5.723367e+06
# dtype: float64
#
# The Maximum value is:: 14904424.997324772
#
# We can predict that debit card is the most used methods by users

# %%
#using matplotlib to plot

# %%
Bank_by_year=Bank[['year','no_atms_on_site', 'no_atms_off_site', 'no_pos_on_line',
       'no_pos_off_line', 'no_credit_cards', 'no_credit_card_atm_txn',
       'no_credit_card_pos_txn', 'no_debit_cards', 'no_debit_card_atm_txn',
       'no_debit_card_pos_txn']].groupby('year').aggregate(np.sum)
Bank_by_year.plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
Bank_by_year=Bank[['year','no_atms_on_site', 'no_atms_off_site', 'no_pos_on_line',
       'no_pos_off_line', 'no_credit_cards', 'no_credit_card_atm_txn',
       'no_credit_card_pos_txn', 'no_debit_cards', 'no_debit_card_atm_txn',
       'no_debit_card_pos_txn']].groupby('year').aggregate(np.sum)
Bank_by_year.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='year'>
